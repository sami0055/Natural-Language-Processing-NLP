# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import requests
import pandas as pd

# Replace 'your_api_key_here' with your actual TMDb API key
api_key = '8265bd1679663a7ea12ac168da84d2e8'

# Function to get movie descriptions
def get_movie_description(movie_id):
    url = f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}&language=en-US'
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        description = data.get('overview', 'N/A')
        title = data.get('title', 'N/A')
        return title, description
    else:
        return None, None

# Function to get movie genres
def get_movie_genres(movie_id):
    url = f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}&language=en-US'
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        genres = [genre['name'] for genre in data.get('genres', [])]
        return genres
    else:
        return []

# Function to fetch movie IDs from a specific page
def get_movie_ids_from_page(page):
    url = f'https://api.themoviedb.org/3/movie/popular?api_key={api_key}&language=en-US&page={page}'
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        return [movie['id'] for movie in data.get('results', [])]
    else:
        return []

# Loop through pages and fetch movie details
all_movie_details = []
for page in range(1, 10):
    print(f"Fetching page {page}")
    movie_ids = get_movie_ids_from_page(page)

    for movie_id in movie_ids:
        title, description = get_movie_description(movie_id)
        genres = get_movie_genres(movie_id)
        if title and description:
            all_movie_details.append({
                'id': movie_id,
                'title': title,
                'description': description,
                'genres': ', '.join(genres)
            })

# Convert the list of movie details to a DataFrame
df = pd.DataFrame(all_movie_details)

# Save DataFrame to a CSV file
df.drop('id', axis=1, inplace=True)
csv_file_path = 'movie_details.csv'
df.to_csv(csv_file_path, index=False)

# Display the DataFrame
print(df)
# Out:
# Fetching page 1
# Fetching page 2
# Fetching page 3
# Fetching page 4
# Fetching page 5
# Fetching page 6
# Fetching page 7
# Fetching page 8
# Fetching page 9
#                                                  title  \
# 0                                         Inside Out 2
# 1                                      Despicable Me 4
# 2                                   The Garfield Movie
# 3                              Furiosa: A Mad Max Saga
# 4                    Kingdom of the Planet of the Apes
# ..                                                 ...
# 173                       Aquaman and the Lost Kingdom
# 174                                             Exhuma
# 175  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...
# 176                                      The Beekeeper
# 177                   The Gangster, the Cop, the Devil
#
#                                            description  \
# 0    Teenager Riley's mind headquarters is undergoi...
# ...

# %%
from google.colab import files

# Download the CSV file
files.download(csv_file_path)

# %%
df=pd.read_csv('movie_details.csv')

# %%
df.shape
# Out:
# (178, 3)

# %%
df.head(20)
# Out:
#                                 title  \
# 0                        Inside Out 2
# 1                     Despicable Me 4
# 2                  The Garfield Movie
# 3             Furiosa: A Mad Max Saga
# 4   Kingdom of the Planet of the Apes
# 5           Beverly Hills Cop: Axel F
# 6                          Monkey Man
# 7               Bad Boys: Ride or Die
# 8     Godzilla x Kong: The New Empire
# 9                 In a Violent Nature
# 10                           Boneyard
# 11         The Jack in the Box: Rises
# 12                        Under Paris
# 13                        Black Noise
# 14                          Civil War
# 15             A Quiet Place: Day One
# 16                    The Infallibles
# 17                    Trigger Warning
# 18                    MR-9: Do or Die
# 19                         Inside Out
#
#                                           description  \
# 0   Teenager Riley's mind headquarters is undergoi...
# ...

# %%
df.shape
# Out:
# (178, 3)

# %%
df['title'] = df['title'].str.lower()
df['description'] = df['description'].str.lower()
df['genres'] = df['genres'].str.lower()

# %%
df.head(5)
# Out:
#                                title  \
# 0                       inside out 2
# 1                    despicable me 4
# 2                 the garfield movie
# 3            furiosa: a mad max saga
# 4  kingdom of the planet of the apes
#
#                                          description  \
# 0  teenager riley's mind headquarters is undergoi...
# 1  gru and lucy and their girls — margo, edith an...
# 2  garfield, the world-famous, monday-hating, las...
# 3  as the world fell, young furiosa is snatched f...
# 4  several generations following caesar's reign, ...
#
#                                         genres
# 0  animation, family, adventure, comedy, drama
# 1            animation, family, comedy, action
# 2         animation, comedy, family, adventure
# 3           action, adventure, science fiction
# 4           science fiction, adventure, action

# %%
df.shape
# Out:
# (178, 3)

# %%
import re
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
df['title'] = df['title'].apply(remove_html_tags)
df['description'] = df['description'].apply(remove_html_tags)
df['genres'] = df['genres'].apply(remove_html_tags)

# %%
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

# %%
df['title'] = df['title'].apply(remove_url)
df['description'] = df['description'].apply(remove_url)
df['genres'] = df['genres'].apply(remove_url)

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
# ...

# %%
def remove_stopwords(text):
    new_text = []

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
df['title'] = df['title'].apply(remove_stopwords)
df['description'] = df['description'].apply(remove_stopwords)
df['genres'] = df['genres'].apply(remove_stopwords)

# %%
from textblob import TextBlob
from multiprocessing import Pool, cpu_count

# %%
# Function to correct spelling using TextBlob
def correct_spelling(text):
    return str(TextBlob(text).correct())

# Function to apply the spelling correction in parallel
def parallel_apply(df, func, num_cores=None):
    if num_cores is None:
        num_cores = cpu_count()

    df_split = np.array_split(df, num_cores)
    pool = Pool(num_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df

# Function to apply correct_spelling to a DataFrame
def correct_spelling_df(df):
    df['title'] = df['title'].apply(correct_spelling)
    df['description'] = df['description'].apply(correct_spelling)
    df['genres'] = df['genres'].apply(correct_spelling)
    return df

# Apply the spelling correction in parallel
df = parallel_apply(df, correct_spelling_df)

# Display the DataFrame with corrected reviews
print(df)
# Out:
#                                               title  \
# 0                                         inside  2
# 1                                     despicable  4
# 2                                    garfield movie
# 3                            furious:  mad max sage
# 4                           kingdom   planet   apes
# ..                                              ...
# 173                          aquaman   lost kingdom
# 174                                          exhuma
# 175  demon layer -kimetsu  labia-  movie: men train
# 176                                       beekeeper
# 177                          canister,  cop,  devil
#
#                                            description  \
# 0    teenager ripley's mind headquarters  undergoin...
# 1    grm  lucy   girls — cargo, edith  agnes — welc...
# 2    garfield,  world-famous, monday-hating, lasagn...
# 3      world fell, young furious  snatched   green ...
# 4    several generations following caesar's reign, ...
# ...

# %%
import re
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
df['title'] = df['title'].apply(remove_emoji)
df['description'] = df['description'].apply(remove_emoji)
df['genres'] = df['genres'].apply(remove_emoji)

# %%
df.head()
# Out:
#                      title                                        description  \
# 0                inside  2  teenager ripley's mind headquarters  undergoin...
# 1            despicable  4  grm  lucy   girls — cargo, edith  agnes — welc...
# 2           garfield movie  garfield,  world-famous, monday-hating, lasagn...
# 3   furious:  mad max sage    world fell, young furious  snatched   green ...
# 4  kingdom   planet   apes  several generations following caesar's reign, ...
#
#                                         genres
# 0  animation, family, adventure, comedy, drama
# 1            animation, family, comedy, action
# 2         animation, comedy, family, adventure
# 3           action, adventure, science fiction
# 4           science fiction, adventure, action

# %%
import pandas as pd
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Initialize the stemmer
stemmer = PorterStemmer()

# Stemming function using NLTK
def stem_text(text):
    tokens = word_tokenize(text)
    return [stemmer.stem(token) for token in tokens]

# Assuming df is your DataFrame
df['title'] = df['title'].apply(stem_text)
df['description'] = df['description'].apply(stem_text)
df['genres'] = df['genres'].apply(stem_text)

# %%
# import pandas as pd
# import spacy

# # Load the spaCy model
# nlp = spacy.load("en_core_web_sm")

# # Lemmatization function using spaCy
# def spacy_lemmatize(text):
#     doc = nlp(text)
#     return [token.lemma_ for token in doc]

# # Assuming df is your DataFrame
# df['title'] = df['title'].apply(spacy_lemmatize)
# df['description'] = df['description'].apply(spacy_lemmatize)
# df['genres'] = df['genres'].apply(spacy_lemmatize)

# %%
df.head()
# Out:
#                          title  \
# 0                   [insid, 2]
# 1                  [despic, 4]
# 2             [garfield, movi]
# 3  [furiou, :, mad, max, sage]
# 4       [kingdom, planet, ape]
#
#                                          description  \
# 0  [teenag, ripley, 's, mind, headquart, undergo,...
# 1  [grm, luci, girl, —, cargo, ,, edith, agn, —, ...
# 2  [garfield, ,, world-fam, ,, monday-h, ,, lasag...
# 3  [world, fell, ,, young, furiou, snatch, green,...
# 4  [sever, gener, follow, caesar, 's, reign, ,, a...
#
#                                               genres
# 0  [anim, ,, famili, ,, adventur, ,, comedi, ,, d...
# 1            [anim, ,, famili, ,, comedi, ,, action]
# 2          [anim, ,, comedi, ,, famili, ,, adventur]
# 3          [action, ,, adventur, ,, scienc, fiction]
# 4          [scienc, fiction, ,, adventur, ,, action]

# %%
# import pandas as pd
# from nltk.tokenize import word_tokenize

# # Assuming df is your DataFrame

# df['title'] = df['title'].apply(word_tokenize)
# df['description'] = df['description'].apply(word_tokenize)
# df['genres'] = df['genres'].apply(word_tokenize)

# %%
df.head()
# Out:
#                          title  \
# 0                   [insid, 2]
# 1                  [despic, 4]
# 2             [garfield, movi]
# 3  [furiou, :, mad, max, sage]
# 4       [kingdom, planet, ape]
#
#                                          description  \
# 0  [teenag, ripley, 's, mind, headquart, undergo,...
# 1  [grm, luci, girl, —, cargo, ,, edith, agn, —, ...
# 2  [garfield, ,, world-fam, ,, monday-h, ,, lasag...
# 3  [world, fell, ,, young, furiou, snatch, green,...
# 4  [sever, gener, follow, caesar, 's, reign, ,, a...
#
#                                               genres
# 0  [anim, ,, famili, ,, adventur, ,, comedi, ,, d...
# 1            [anim, ,, famili, ,, comedi, ,, action]
# 2          [anim, ,, comedi, ,, famili, ,, adventur]
# 3          [action, ,, adventur, ,, scienc, fiction]
# 4          [scienc, fiction, ,, adventur, ,, action]

# %%
# import pandas as pd
# import spacy

# # Load the spaCy model
# nlp = spacy.load("en_core_web_sm")

# # Tokenization function using spaCy
# def spacy_tokenize(text):
#     return [token.text for token in nlp(text)]

# # Assuming df is your DataFrame
# df['titile'] = df['titile'].apply(spacy_tokenize)
# df['description'] = df['description'].apply(spacy_tokenize)
# df['genres'] = df['genres'].apply(spacy_tokenize)

# %%
df.head(5)
# Out:
#                           title  \
# 0                   [inside, 2]
# 1               [despicable, 4]
# 2             [garfield, movie]
# 3  [furious, :, mad, max, sage]
# 4       [kingdom, planet, apes]
#
#                                          description  \
# 0  [teenager, ripley, 's, mind, headquarters, und...
# 1  [grm, lucy, girls, —, cargo, ,, edith, agnes, ...
# 2  [garfield, ,, world-famous, ,, monday-hating, ...
# 3  [world, fell, ,, young, furious, snatched, gre...
# 4  [several, generations, following, caesar, 's, ...
#
#                                               genres
# 0  [animation, ,, family, ,, adventure, ,, comedy...
# 1       [animation, ,, family, ,, comedy, ,, action]
# 2    [animation, ,, comedy, ,, family, ,, adventure]
# 3        [action, ,, adventure, ,, science, fiction]
# 4        [science, fiction, ,, adventure, ,, action]

# %%
def remove_punc1(text):
    return text.translate(str.maketrans('', '', exclude))

# %%
import string,time
string.punctuation
exclude = string.punctuation

# %%
# df['title'] = df['titile'].apply(remove_punc1)
# df['description'] = df['description'].apply(remove_punc1)
# df['genres'] = df['genres'].apply(remove_punc1)

# %%
df.head()
# Out:
#                                          description  \
# 0  teenager rileys mind headquarters is undergoin...
# 1  gru and lucy and their girls — margo edith and...
# 2  garfield the worldfamous mondayhating lasagnal...
# 3  as the world fell young furiosa is snatched fr...
# 4  several generations following caesars reign ap...
#
#                                     genres                             titile
# 0  animation family adventure comedy drama                       inside out 2
# 1           animation family comedy action                    despicable me 4
# 2        animation comedy family adventure                 the garfield movie
# 3         action adventure science fiction             furiosa a mad max saga
# 4         science fiction adventure action  kingdom of the planet of the apes

# %%
# import emoji
# print(emoji.demojize('Python is 🔥'))

# %%
import re
sent3 = 'I am going to delhi!'
tokens = re.findall("[\w']+", sent3)
tokens
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""
sentences = re.compile('[.!?] ').split(text)
sentences
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry',
#  "\nLorem Ipsum has been the industry's standard dummy text ever since the 1500s, \nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent1 = 'I am going to visit delhi!'
word_tokenize(sent1)
# Out:
# ['I', 'am', 'going', 'to', 'visit', 'delhi', '!']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""

sent_tokenize(text)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, \nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
sent5 = 'I have a Ph.D in A.I'
sent6 = "We're here to help! mail us at nks@gmail.com"
sent7 = 'A 5km ride cost $10.50'

word_tokenize(sent5)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I']

# %%
word_tokenize(sent6)
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  '!',
#  'mail',
#  'us',
#  'at',
#  'nks',
#  '@',
#  'gmail.com']

# %%
word_tokenize(sent7)
# Out:
# ['A', '5km', 'ride', 'cost', '$', '10.50']

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(sent5)
doc2 = nlp(sent6)
doc3 = nlp(sent7)
doc4 = nlp(sent1)

# %%
for token in doc3:
    print(token)
# Out:
# A
# 5
# km
# ride
# cost
# $
# 10.50
